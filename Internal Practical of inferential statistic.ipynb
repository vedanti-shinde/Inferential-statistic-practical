# %%
#Ex.1.check the goodnessof fit for thr following data mapping number of hours a student studies v/s the expected number of hours at 5 % los.
#observed data (in hours) = [8,6,10,7,8,11,9]
#Expected data (in hours) = [9,8,11,8,10,7,6]
from scipy.stats import chisquare
observed = [8, 6, 10, 7, 8, 11, 9]
expected = [9, 8, 11, 8, 10, 7, 6]
chi_stat, p_value = chisquare(f_obs=observed, f_exp=expected)
print("Chi-Square Statistic =", chi_stat)
print("P-Value =", p_value)

#los
alpha = 0.05
if p_value < alpha:
    print("Reject Null Hypothesis")
else:
    print("Fail to Reject Null Hypothesis")
# Out:
# Chi-Square Statistic = 5.0127344877344875
# P-Value = 0.542180861413329
# Fail to Reject Null Hypothesis

# %%
#what is the probability of 2 heads in 6 coin tosses? Fit the binnomial diatribution for coin tosses and plot it
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom
n = 6
p = 0.5
# possible number of heads
x = np.arange(0, n + 1)
# binomial prob
prob = binom.pmf(x, n, p)
# probability of exactly 2 heads
print("Probability of exactly 2 heads =", prob[2])

plt.bar(x, prob)
plt.xlabel("Number of Heads")
plt.ylabel("Probability")
plt.title("Binomial Distribution for 6 Coin Tosses")

plt.show()
# Out:
# Probability of exactly 2 heads = 0.23437500000000003
